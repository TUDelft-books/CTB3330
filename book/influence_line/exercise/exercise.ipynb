# %% [markdown]
# # Exercise

# %% [markdown]
# Given is the following structure:
#
# ```{figure} ./structure.svg
# ---
# width: 400px
# name: 3sup
# align: center
# ---
# Statically indeterminate structure with 3 supports
# ```

# %% [markdown]
# ````{exercise} Influence line support reaction at A
# :label: exercise_A
# :nonumber: true
#
# Draw the influence line for the [support reaction at A](3sup), assuming a positive support reaction to point upwards. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532320235395937/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_A
# :class: dropdown
#
# ![](./Av.svg)
#
# See an interactive plot of this influence line on [this page](../influence_line_3sup/Interactive_influence_line_Av.ipynb) (slow on phones)
# ```

# %% [markdown]
# ````{exercise} Influence line shear force just left of B
# :label: exercise_B
# :nonumber: true
#
# Draw the influence line for the shear force just left of B. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532320235395937/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_B
# :class: dropdown
#
# ![](./VB.svg)
#
# See an interactive plot of this influence line on [this page](../influence_line_3sup/Interactive_influence_line_V.ipynb) (slow on phones)
# ```

# %% [markdown]
# ````{exercise} Influence line moment in B
# :label: exercise_C
# :nonumber: true
#
# Draw the influence line for the moment in B. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532328998700507/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_C
# :class: dropdown
#
# ![](./MB.svg)
#
# See an interactive plot of this influence line on [this page](../influence_line_3sup/Interactive_influence_line_M.ipynb) (slow on phones)
# ```

# %% [markdown]
# ````{exercise} Influence line shear force in D
# :label: exercise_D
# :nonumber: true
#
# Draw the influence line for the shear force in D. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532320235395937/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_D
# :class: dropdown
#
# ![](./VD.svg)
#
# See an interactive plot of this influence line on [this page](../influence_line_3sup/Interactive_influence_line_V.ipynb) (slow on phones)
# ```

# %% [markdown]
# ````{exercise} Influence line moment in D
# :label: exercise_E
# :nonumber: true
#
# Draw the influence line for the moment in D. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532328998700507/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_E
# :class: dropdown
#
# ![](./MD.svg)
#
# See an interactive plot of this influence line on [this page](../influence_line_3sup/Interactive_influence_line_M.ipynb) (slow on phones)
# ```

# %% [markdown]
# ````{exercise} Influence line shear force just right of D
# :label: exercise_F
# :nonumber: true
#
# Draw the influence line for the shear force just right of D. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532328998700507/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_F
# :class: dropdown
#
# ![](./VBR.svg)
#
# See an interactive plot of this influence line on [this page](../influence_line_3sup/Interactive_influence_line_V.ipynb) (slow on phones)
# ```

# %% [markdown]
# Given is the following structure:
#
# ```{figure} ./structure2.svg
# ---
# width: 400px
# name: 3sup
# align: center
# ---
# Statically indeterminate structure with 3 supports
# ```

# %% [markdown]
# ````{exercise} Influence line displacement of D
# :label: exercise_G
# :nonumber: true
#
# Draw the influence line for the displacement of D. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532348178732857/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_G
# :class: dropdown
#
# ![](./inf1.svg)
#
# ```

# %% [markdown]
# ````{exercise} Influence line rotation of B
# :label: exercise_H
# :nonumber: true
#
# Draw the influence line for the rotation of B. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532348178732857/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_H
# :class: dropdown
#
# ![](./inf2.svg)
#
# ```

# %% [markdown]
# ````{exercise} Influence line displacement of S2
# :label: exercise_I
# :nonumber: true
#
# Draw the influence line for the rotation of S2. Only indicate the values for which no calculations are required.
#
# ```{h5p} https://tudelft.h5p.com/content/1292532353901260487/embed
# ```
# ````

# %% [markdown]
# ```{solution} exercise_I
# :class: dropdown
#
# ![](./inf3.svg)
#
# ```
